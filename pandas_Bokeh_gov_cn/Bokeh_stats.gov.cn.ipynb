# %% [markdown]
# # 分省指标数据之使用与制图
# * 数据处理+制图 使用[pandas](http://pandas.pydata.org/pandas-docs/stable/install.html)
# * 制图 使用 [bokeh](http://bokeh.pydata.org/en/latest/docs/installation.html)

# %% [markdown]
# ## (1) 取/连结 数据

# %%
import pandas as pd   # 数据分析模块 （Python Data Analysis Library Python）

# %%
# 列出同目录之.csv档以检查
import glob
print(glob.glob("*.csv"))
# Out:
# ['fsnd_GDP_A020101.csv', 'fsnd_POP_A030101.csv', 'gongshui.csv', 'pop.csv']

# %%
# 第1次尝试 
# 读GDP数据，赋与df   (df指 dataframe)   pd.DataFrame 是前面最早调用的 pandas
df_try = pd.read_table("gongshui.csv",   # 档名
                          encoding='utf8', # 编码
                      )
# 出错的话，是国家数据网下载的数据并没有用 UTF-8 (档首无BOM)编码
# 使用Notepad++按编码-->  转换至  UTF-8 (档首无BOM)编码

# %%
# 看看有什麽？
df_try
# Out:
#                                            数据库：分省年度数据
# 0                                      指标：水资源总量(亿立方米)
# 1                                            时间：最近10年
# 2   地区,2015年,2014年,2013年,2012年,2011年,2010年,2009年,2...
# 3   北京市,26.80,20.30,24.81,39.50,26.81,23.10,21.84,...
# 4   天津市,12.80,11.37,14.64,32.94,15.39,9.20,15.24,1...
# 5   河北省,135.10,106.16,175.86,235.53,157.15,138.90,...
# 6   山西省,94.00,111.01,126.55,106.25,124.34,91.50,85...
# 7   内蒙古自治区,537.00,537.79,959.81,510.25,419.00,388....
# 8   辽宁省,179.00,145.93,463.17,547.30,294.79,606.70,...
# 9   吉林省,331.30,306.03,607.40,460.47,315.89,686.70,...
# 10  黑龙江省,814.10,944.34,1419.58,841.41,629.48,853.5...
# 11  上海市,64.10,47.15,28.03,33.90,20.72,36.80,41.57,...
# 12  江苏省,582.10,399.34,283.53,373.33,492.40,383.50,...
# 13  浙江省,1407.10,1132.15,931.34,1444.79,744.96,1398...
# 14  安徽省,914.10,778.48,585.59,701.00,602.25,922.80,...
# 15  福建省,1325.90,1219.62,1151.90,1511.44,774.85,165...
# 16  江西省,2001.20,1631.81,1423.99,2174.36,1037.88,22...
# 17  山东省,168.40,148.44,291.70,274.30,347.63,309.10,...
# 18  河南省,287.20,283.36,213.07,265.54,327.97,534.90,...
# 19  湖北省,1015.60,914.29,790.15,813.88,757.54,1268.7...
# 20  湖南省,1919.30,1799.43,1581.97,1988.94,1126.94,19...
# 21  广东省,1933.40,1718.45,2263.17,2026.55,1471.26,19...
# 22  广西壮族自治区,2433.60,1990.90,2057.33,2087.40,1350.0...
# 23  海南省,198.20,383.51,502.11,364.31,484.10,479.80,...
# 24  重庆市,456.20,642.58,474.35,476.89,514.58,464.30,...
# 25  四川省,2220.50,2557.66,2470.27,2892.36,2239.49,25...
# 26  贵州省,1153.70,1213.12,759.44,974.02,626.02,956.5...
# 27  云南省,1871.90,1726.63,1706.69,1689.77,1480.20,19...
# 28  西藏自治区,3853.00,4416.30,4415.74,4196.35,4402.71,...
# 29  陕西省,333.40,351.64,353.78,390.49,604.42,507.50,...
# 30  甘肃省,164.80,198.38,268.90,266.95,242.21,215.20,...
# 31  青海省,589.30,793.86,645.61,895.22,733.12,741.10,...
# 32  宁夏回族自治区,9.20,10.07,11.40,10.81,8.76,9.30,8.42,...
# 33  新疆维吾尔自治区,930.30,726.93,955.99,900.63,885.65,11...
# 34                                         数据来源：国家统计局

# %%
# 第2次尝试 
# 指定数据标题为原始数据之第几行
df    = pd.read_table("gongshui.csv",   # 档名
                       encoding = 'utf8',       # 编码
                       header = 3               # 指定数据的标题为原始数据之第3行
                     )
df
# Out:
#    地区,2015年,2014年,2013年,2012年,2011年,2010年,2009年,2008年,2007年,2006年
# 0   北京市,26.80,20.30,24.81,39.50,26.81,23.10,21.84,...
# 1   天津市,12.80,11.37,14.64,32.94,15.39,9.20,15.24,1...
# 2   河北省,135.10,106.16,175.86,235.53,157.15,138.90,...
# 3   山西省,94.00,111.01,126.55,106.25,124.34,91.50,85...
# 4   内蒙古自治区,537.00,537.79,959.81,510.25,419.00,388....
# 5   辽宁省,179.00,145.93,463.17,547.30,294.79,606.70,...
# 6   吉林省,331.30,306.03,607.40,460.47,315.89,686.70,...
# 7   黑龙江省,814.10,944.34,1419.58,841.41,629.48,853.5...
# 8   上海市,64.10,47.15,28.03,33.90,20.72,36.80,41.57,...
# 9   江苏省,582.10,399.34,283.53,373.33,492.40,383.50,...
# 10  浙江省,1407.10,1132.15,931.34,1444.79,744.96,1398...
# 11  安徽省,914.10,778.48,585.59,701.00,602.25,922.80,...
# 12  福建省,1325.90,1219.62,1151.90,1511.44,774.85,165...
# 13  江西省,2001.20,1631.81,1423.99,2174.36,1037.88,22...
# 14  山东省,168.40,148.44,291.70,274.30,347.63,309.10,...
# 15  河南省,287.20,283.36,213.07,265.54,327.97,534.90,...
# 16  湖北省,1015.60,914.29,790.15,813.88,757.54,1268.7...
# 17  湖南省,1919.30,1799.43,1581.97,1988.94,1126.94,19...
# 18  广东省,1933.40,1718.45,2263.17,2026.55,1471.26,19...
# 19  广西壮族自治区,2433.60,1990.90,2057.33,2087.40,1350.0...
# 20  海南省,198.20,383.51,502.11,364.31,484.10,479.80,...
# 21  重庆市,456.20,642.58,474.35,476.89,514.58,464.30,...
# 22  四川省,2220.50,2557.66,2470.27,2892.36,2239.49,25...
# 23  贵州省,1153.70,1213.12,759.44,974.02,626.02,956.5...
# 24  云南省,1871.90,1726.63,1706.69,1689.77,1480.20,19...
# 25  西藏自治区,3853.00,4416.30,4415.74,4196.35,4402.71,...
# 26  陕西省,333.40,351.64,353.78,390.49,604.42,507.50,...
# 27  甘肃省,164.80,198.38,268.90,266.95,242.21,215.20,...
# 28  青海省,589.30,793.86,645.61,895.22,733.12,741.10,...
# 29  宁夏回族自治区,9.20,10.07,11.40,10.81,8.76,9.30,8.42,...
# 30  新疆维吾尔自治区,930.30,726.93,955.99,900.63,885.65,11...
# 31                                         数据来源：国家统计局

# %%
# 第3次尝试
# 使用skiprows 跳过上面的最後2行
df    = pd.read_table("gongshui.csv",   # 档名
                       encoding = 'utf8',       # 编码
                       header = 3,              # 指定数据的标题为原始数据之第3行
                       skiprows = [35,36]       # 原始数据之第35, 36行跳过不计
                     )
df
# Out:
#    地区,2015年,2014年,2013年,2012年,2011年,2010年,2009年,2008年,2007年,2006年
# 0   北京市,26.80,20.30,24.81,39.50,26.81,23.10,21.84,...
# 1   天津市,12.80,11.37,14.64,32.94,15.39,9.20,15.24,1...
# 2   河北省,135.10,106.16,175.86,235.53,157.15,138.90,...
# 3   山西省,94.00,111.01,126.55,106.25,124.34,91.50,85...
# 4   内蒙古自治区,537.00,537.79,959.81,510.25,419.00,388....
# 5   辽宁省,179.00,145.93,463.17,547.30,294.79,606.70,...
# 6   吉林省,331.30,306.03,607.40,460.47,315.89,686.70,...
# 7   黑龙江省,814.10,944.34,1419.58,841.41,629.48,853.5...
# 8   上海市,64.10,47.15,28.03,33.90,20.72,36.80,41.57,...
# 9   江苏省,582.10,399.34,283.53,373.33,492.40,383.50,...
# 10  浙江省,1407.10,1132.15,931.34,1444.79,744.96,1398...
# 11  安徽省,914.10,778.48,585.59,701.00,602.25,922.80,...
# 12  福建省,1325.90,1219.62,1151.90,1511.44,774.85,165...
# 13  江西省,2001.20,1631.81,1423.99,2174.36,1037.88,22...
# 14  山东省,168.40,148.44,291.70,274.30,347.63,309.10,...
# 15  河南省,287.20,283.36,213.07,265.54,327.97,534.90,...
# 16  湖北省,1015.60,914.29,790.15,813.88,757.54,1268.7...
# 17  湖南省,1919.30,1799.43,1581.97,1988.94,1126.94,19...
# 18  广东省,1933.40,1718.45,2263.17,2026.55,1471.26,19...
# 19  广西壮族自治区,2433.60,1990.90,2057.33,2087.40,1350.0...
# 20  海南省,198.20,383.51,502.11,364.31,484.10,479.80,...
# 21  重庆市,456.20,642.58,474.35,476.89,514.58,464.30,...
# 22  四川省,2220.50,2557.66,2470.27,2892.36,2239.49,25...
# 23  贵州省,1153.70,1213.12,759.44,974.02,626.02,956.5...
# 24  云南省,1871.90,1726.63,1706.69,1689.77,1480.20,19...
# 25  西藏自治区,3853.00,4416.30,4415.74,4196.35,4402.71,...
# 26  陕西省,333.40,351.64,353.78,390.49,604.42,507.50,...
# 27  甘肃省,164.80,198.38,268.90,266.95,242.21,215.20,...
# 28  青海省,589.30,793.86,645.61,895.22,733.12,741.10,...
# 29  宁夏回族自治区,9.20,10.07,11.40,10.81,8.76,9.30,8.42,...
# 30  新疆维吾尔自治区,930.30,726.93,955.99,900.63,885.65,11...

# %%
# 第4次尝试
# 分隔符改设
df    = pd.read_table("gongshui.csv",   # 档名
                       encoding = 'utf8',       # 编码
                       header = 3,              # 指定数据的标题为原始数据之第3行
                       skiprows = [35,36],      # 原始数据之第35, 36行跳过不计
                       sep =','                 # 分隔符设为',' read_table内置分隔符为\t
                     )
df
# Out:
#           地区   2015年    2014年    2013年    2012年    2011年   2010年    2009年  \
# 0        北京市    26.8    20.30    24.81    39.50    26.81    23.1    21.84
# 1        天津市    12.8    11.37    14.64    32.94    15.39     9.2    15.24
# 2        河北省   135.1   106.16   175.86   235.53   157.15   138.9   141.16
# 3        山西省    94.0   111.01   126.55   106.25   124.34    91.5    85.76
# 4     内蒙古自治区   537.0   537.79   959.81   510.25   419.00   388.5   378.15
# 5        辽宁省   179.0   145.93   463.17   547.30   294.79   606.7   170.96
# 6        吉林省   331.3   306.03   607.40   460.47   315.89   686.7   298.04
# 0     北京市   26.8   20.30   24.81   39.50   26.81   23.1   21.84   34.2
# 1     天津市   12.8   11.37   14.64   32.94   15.39    9.2   15.24   18.3
# 2     河北省  135.1  106.16  175.86  235.53  157.15  138.9  141.16  161.0
# 3     山西省   94.0  111.01  126.55  106.25  124.34   91.5   85.76   87.4
# 4  内蒙古自治区  537.0  537.79  959.81  510.25  419.00  388.5  378.15  412.1
#
#     2007年   2006年
# 0   23.81   22.07
# 1   11.31   10.11
# 2  119.79  107.34
# 3  103.40   88.52
# 4  295.86  411.29

# %%
# 小结：要处理数据得看原始数据的格式好不好处理
# 现在读2个数据，分别放在df_GDP及df_POP
df_gongshui= pd.read_table("gongshui.csv",   # 档名
                       encoding = 'utf8',       # 编码
                       header = 3,              # 指定数据的标题为原始数据之第3行
                       skiprows = [35,36],      # 原始数据之第35, 36行跳过不计
                       sep =','                 # 分隔符设为',' read_table内置分隔符为\t
                      )
df_POP= pd.read_table("pop.csv",   # 档名
                       encoding = 'utf8',       # 编码
                       header = 3,              # 指定数据的标题为原始数据之第3行
                       skiprows = [35,36],      # 原始数据之第35, 36行跳过不计
                       sep =','                 # 分隔符设为',' read_table内置分隔符为\t
                      )

# %% [markdown]
# ## (2) 准备 数据  （型态）
# * 此练习目标在於取最新一年的数据
# * 比较这两指标数据是否有关连性
# * i.e. 人口较多是否和产值较多相关连

# %%
# 先处理 df_GDP
df = df_gongshui

# %%
# 目前之columns列
df.columns
# Out:
# Index(['地区', '2015年', '2014年', '2013年', '2012年', '2011年', '2010年', '2009年',
#        '2008年', '2007年', '2006年'],
#       dtype='object')

# %%
# 目前之index 索引(栏)
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df['地区'].head()
# Out:
# 0       北京市
# 1       天津市
# 2       河北省
# 3       山西省
# 4    内蒙古自治区
# Name: 地区, dtype: object

# %%
# 此写法不行，不能以数字开头 
df.2007年
# Out:
#   File "<ipython-input-134-636ec1e109bc>", line 2
#     df.2007年
#           ^
# SyntaxError: invalid syntax

# %%
# 此写法可以
df['2007年'].head()
# Out:
# 0     23.81
# 1     11.31
# 2    119.79
# 3    103.40
# 4    295.86
# Name: 2007年, dtype: float64

# %%
# 数据型态dtypes 
df.dtypes
# Out:
# 地区        object
# 2015年    float64
# 2014年    float64
# 2013年    float64
# 2012年    float64
# 2011年    float64
# 2010年    float64
# 2009年    float64
# 2008年    float64
# 2007年    float64
# 2006年    float64
# dtype: object

# %%
# 把df 的栏位用列表推导的方式清理掉'年'这个字符後转换成整数
df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns]
df.columns
# Out:
# Index(['地区', 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006], dtype='object')

# %%
# 求最新的一年
years = [ x for x in df.columns if x!='地区'] 
max(years)
# Out:
# 2015

# %%
# pd.melt() 相当於Tableau 的数据透视
df_melted = pd.melt(df, id_vars=['地区'], value_vars=years)

# %%
df_melted.columns
# Out:
# Index(['地区', 'variable', 'value'], dtype='object')

# %%
df_melted.columns = ['地区', '年', 'gongshui']
df_melted
# Out:
#            地区     年  gongshui
# 0         北京市  2015     26.80
# 1         天津市  2015     12.80
# 2         河北省  2015    135.10
# 3         山西省  2015     94.00
# 4      内蒙古自治区  2015    537.00
# 5         辽宁省  2015    179.00
# 6         吉林省  2015    331.30
# 7        黑龙江省  2015    814.10
# 8         上海市  2015     64.10
# 9         江苏省  2015    582.10
# 10        浙江省  2015   1407.10
# 11        安徽省  2015    914.10
# 12        福建省  2015   1325.90
# 13        江西省  2015   2001.20
# 14        山东省  2015    168.40
# 15        河南省  2015    287.20
# 16        湖北省  2015   1015.60
# 17        湖南省  2015   1919.30
# 18        广东省  2015   1933.40
# 19    广西壮族自治区  2015   2433.60
# 20        海南省  2015    198.20
# 21        重庆市  2015    456.20
# 22        四川省  2015   2220.50
# 23        贵州省  2015   1153.70
# 24        云南省  2015   1871.90
# 25      西藏自治区  2015   3853.00
# 26        陕西省  2015    333.40
# 27        甘肃省  2015    164.80
# 28        青海省  2015    589.30
# 29    宁夏回族自治区  2015      9.20
# ..        ...   ...       ...
# 280       天津市  2006     10.11
# 281       河北省  2006    107.34
# 282       山西省  2006     88.52
# 283    内蒙古自治区  2006    411.29
# 284       辽宁省  2006    261.36
# 285       吉林省  2006    353.63
# 286      黑龙江省  2006    727.93
# 287       上海市  2006     27.64
# 288       江苏省  2006    404.40
# 289       浙江省  2006    903.59
# 290       安徽省  2006    580.50
# 291       福建省  2006   1623.48
# 292       江西省  2006   1629.97
# 293       山东省  2006    199.32
# 294       河南省  2006    321.78
# 295       湖北省  2006    639.69
# 296       湖南省  2006   1770.29
# 297       广东省  2006   2216.17
# 298   广西壮族自治区  2006   1881.08
# 299       海南省  2006    227.59
# 300       重庆市  2006    380.32
# 301       四川省  2006   1865.84
# 302       贵州省  2006    814.63
# 303       云南省  2006   1711.67
# 304     西藏自治区  2006   4157.14
# 305       陕西省  2006    275.51
# 306       甘肃省  2006    184.59
# 307       青海省  2006    569.00
# 308   宁夏回族自治区  2006     10.61
# 309  新疆维吾尔自治区  2006    953.10
#
# [310 rows x 3 columns]

# %%
df_gongshui_done = df_melted

# %%
# 再处理 df_POP
df = df_POP
df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns]
years = [ x for x in df.columns if x!='地区'] 
df_melted = pd.melt(df, id_vars=['地区'], value_vars=years)
df_melted.columns = ['地区', '年', 'POP']
df_POP_done = df_melted
df_POP_done
# Out:
#            地区     年    POP
# 0         北京市  2015   2171
# 1         天津市  2015   1547
# 2         河北省  2015   7425
# 3         山西省  2015   3664
# 4      内蒙古自治区  2015   2511
# 5         辽宁省  2015   4382
# 6         吉林省  2015   2753
# 7        黑龙江省  2015   3812
# 8         上海市  2015   2415
# 9         江苏省  2015   7976
# 10        浙江省  2015   5539
# 11        安徽省  2015   6144
# 12        福建省  2015   3839
# 13        江西省  2015   4566
# 14        山东省  2015   9847
# 15        河南省  2015   9480
# 16        湖北省  2015   5852
# 17        湖南省  2015   6783
# 18        广东省  2015  10849
# 19    广西壮族自治区  2015   4796
# 20        海南省  2015    911
# 21        重庆市  2015   3017
# 22        四川省  2015   8204
# 23        贵州省  2015   3530
# 24        云南省  2015   4742
# 25      西藏自治区  2015    324
# 26        陕西省  2015   3793
# 27        甘肃省  2015   2600
# 28        青海省  2015    588
# 29    宁夏回族自治区  2015    668
# ..        ...   ...    ...
# 280       天津市  2006   1075
# 281       河北省  2006   6898
# 282       山西省  2006   3375
# 283    内蒙古自治区  2006   2415
# 284       辽宁省  2006   4271
# 285       吉林省  2006   2723
# 286      黑龙江省  2006   3823
# 287       上海市  2006   1964
# 288       江苏省  2006   7656
# 289       浙江省  2006   5072
# 290       安徽省  2006   6110
# 291       福建省  2006   3585
# 292       江西省  2006   4339
# 293       山东省  2006   9309
# 294       河南省  2006   9392
# 295       湖北省  2006   5693
# 296       湖南省  2006   6342
# 297       广东省  2006   9442
# 298   广西壮族自治区  2006   4719
# 299       海南省  2006    836
# 300       重庆市  2006   2808
# 301       四川省  2006   8169
# 302       贵州省  2006   3690
# 303       云南省  2006   4483
# 304     西藏自治区  2006    285
# 305       陕西省  2006   3699
# 306       甘肃省  2006   2547
# 307       青海省  2006    548
# 308   宁夏回族自治区  2006    604
# 309  新疆维吾尔自治区  2006   2050
#
# [310 rows x 3 columns]

# %% [markdown]
# ## (3) 连结两个数据

# %%
df_p = df_POP_done.join(df_gongshui_done,lsuffix='', rsuffix='_gongshui')
df_p
# Out:
#            地区     年    POP 地区_gongshui 年_gongshui  gongshui
# 0         北京市  2015   2171         北京市       2015     26.80
# 1         天津市  2015   1547         天津市       2015     12.80
# 2         河北省  2015   7425         河北省       2015    135.10
# 3         山西省  2015   3664         山西省       2015     94.00
# 4      内蒙古自治区  2015   2511      内蒙古自治区       2015    537.00
# 5         辽宁省  2015   4382         辽宁省       2015    179.00
# 6         吉林省  2015   2753         吉林省       2015    331.30
# 7        黑龙江省  2015   3812        黑龙江省       2015    814.10
# 8         上海市  2015   2415         上海市       2015     64.10
# 9         江苏省  2015   7976         江苏省       2015    582.10
# 10        浙江省  2015   5539         浙江省       2015   1407.10
# 11        安徽省  2015   6144         安徽省       2015    914.10
# 12        福建省  2015   3839         福建省       2015   1325.90
# 13        江西省  2015   4566         江西省       2015   2001.20
# 14        山东省  2015   9847         山东省       2015    168.40
# 15        河南省  2015   9480         河南省       2015    287.20
# 16        湖北省  2015   5852         湖北省       2015   1015.60
# 17        湖南省  2015   6783         湖南省       2015   1919.30
# 18        广东省  2015  10849         广东省       2015   1933.40
# 19    广西壮族自治区  2015   4796     广西壮族自治区       2015   2433.60
# 20        海南省  2015    911         海南省       2015    198.20
# 21        重庆市  2015   3017         重庆市       2015    456.20
# 22        四川省  2015   8204         四川省       2015   2220.50
# 23        贵州省  2015   3530         贵州省       2015   1153.70
# 24        云南省  2015   4742         云南省       2015   1871.90
# 25      西藏自治区  2015    324       西藏自治区       2015   3853.00
# 26        陕西省  2015   3793         陕西省       2015    333.40
# 27        甘肃省  2015   2600         甘肃省       2015    164.80
# 28        青海省  2015    588         青海省       2015    589.30
# 29    宁夏回族自治区  2015    668     宁夏回族自治区       2015      9.20
# ..        ...   ...    ...         ...        ...       ...
# 280       天津市  2006   1075         天津市       2006     10.11
# 281       河北省  2006   6898         河北省       2006    107.34
# 282       山西省  2006   3375         山西省       2006     88.52
# 283    内蒙古自治区  2006   2415      内蒙古自治区       2006    411.29
# 284       辽宁省  2006   4271         辽宁省       2006    261.36
# 285       吉林省  2006   2723         吉林省       2006    353.63
# 286      黑龙江省  2006   3823        黑龙江省       2006    727.93
# 287       上海市  2006   1964         上海市       2006     27.64
# 293       山东省  2006   9309    199.32
# 294       河南省  2006   9392    321.78
# 295       湖北省  2006   5693    639.69
# 296       湖南省  2006   6342   1770.29
# 297       广东省  2006   9442   2216.17
# 298   广西壮族自治区  2006   4719   1881.08
# 299       海南省  2006    836    227.59
# 300       重庆市  2006   2808    380.32
# 301       四川省  2006   8169   1865.84
# 302       贵州省  2006   3690    814.63
# 303       云南省  2006   4483   1711.67
# 304     西藏自治区  2006    285   4157.14
# 305       陕西省  2006   3699    275.51
# 306       甘肃省  2006   2547    184.59
# 307       青海省  2006    548    569.00
# 308   宁夏回族自治区  2006    604     10.61
# 309  新疆维吾尔自治区  2006   2050    953.10
#
# [310 rows x 4 columns]

# %%
df_p.drop(["地区_gongshui","年_gongshui"], axis=1).set_index(["地区","年"])
# Out:
#                  POP  gongshui
# 地区       年
# 北京市      2015   2171     26.80
# 天津市      2015   1547     12.80
# 河北省      2015   7425    135.10
# 山西省      2015   3664     94.00
# 内蒙古自治区   2015   2511    537.00
# 辽宁省      2015   4382    179.00
# 吉林省      2015   2753    331.30
# 黑龙江省     2015   3812    814.10
# 上海市      2015   2415     64.10
# 江苏省      2015   7976    582.10
# 浙江省      2015   5539   1407.10
# 安徽省      2015   6144    914.10
# 福建省      2015   3839   1325.90
# 江西省      2015   4566   2001.20
# 山东省      2015   9847    168.40
# 河南省      2015   9480    287.20
# 湖北省      2015   5852   1015.60
# 湖南省      2015   6783   1919.30
# 广东省      2015  10849   1933.40
# 广西壮族自治区  2015   4796   2433.60
# 海南省      2015    911    198.20
# 重庆市      2015   3017    456.20
# 四川省      2015   8204   2220.50
# 贵州省      2015   3530   1153.70
# 云南省      2015   4742   1871.90
# 西藏自治区    2015    324   3853.00
# 陕西省      2015   3793    333.40
# 甘肃省      2015   2600    164.80
# 青海省      2015    588    589.30
# 宁夏回族自治区  2015    668      9.20
# ...              ...       ...
# 天津市      2006   1075     10.11
# 河北省      2006   6898    107.34
# 山西省      2006   3375     88.52
# 内蒙古自治区   2006   2415    411.29
# 辽宁省      2006   4271    261.36
# 吉林省      2006   2723    353.63
# 黑龙江省     2006   3823    727.93
# 上海市      2006   1964     27.64
# 江苏省      2006   7656    404.40
# 浙江省      2006   5072    903.59
# 安徽省      2006   6110    580.50
# 福建省      2006   3585   1623.48
# 江西省      2006   4339   1629.97
# 山东省      2006   9309    199.32
# 河南省      2006   9392    321.78
# 湖北省      2006   5693    639.69
# 湖南省      2006   6342   1770.29
# 广东省      2006   9442   2216.17
# 广西壮族自治区  2006   4719   1881.08
# 海南省      2006    836    227.59
# 重庆市      2006   2808    380.32
# 四川省      2006   8169   1865.84
# 贵州省      2006   3690    814.63
# 云南省      2006   4483   1711.67
# 西藏自治区    2006    285   4157.14
# 陕西省      2006   3699    275.51
# 甘肃省      2006   2547    184.59
# 青海省      2006    548    569.00
# 宁夏回族自治区  2006    604     10.61
# 新疆维吾尔自治区 2006   2050    953.10
#
# [310 rows x 2 columns]

# %%
df_pp = df_p.drop(["地区_gongshui","年_gongshui"], axis=1).set_index(["地区","年"])

# %%
df_pp.query("年==2015")
# Out:
#                  POP  gongshui
# 地区       年
# 北京市      2015   2171      26.8
# 天津市      2015   1547      12.8
# 河北省      2015   7425     135.1
# 山西省      2015   3664      94.0
# 内蒙古自治区   2015   2511     537.0
# 辽宁省      2015   4382     179.0
# 吉林省      2015   2753     331.3
# 黑龙江省     2015   3812     814.1
# 上海市      2015   2415      64.1
# 江苏省      2015   7976     582.1
# 浙江省      2015   5539    1407.1
# 安徽省      2015   6144     914.1
# 福建省      2015   3839    1325.9
# 江西省      2015   4566    2001.2
# 山东省      2015   9847     168.4
# 河南省      2015   9480     287.2
# 湖北省      2015   5852    1015.6
# 湖南省      2015   6783    1919.3
# 广东省      2015  10849    1933.4
# 广西壮族自治区  2015   4796    2433.6
# 海南省      2015    911     198.2
# 重庆市      2015   3017     456.2
# 四川省      2015   8204    2220.5
# 贵州省      2015   3530    1153.7
# 云南省      2015   4742    1871.9
# 西藏自治区    2015    324    3853.0
# 陕西省      2015   3793     333.4
# 甘肃省      2015   2600     164.8
# 青海省      2015    588     589.3
# 宁夏回族自治区  2015    668       9.2
# 新疆维吾尔自治区 2015   2360     930.3

# %% [markdown]
# ## (4) 可视化 使用pands 自带的plot来制图

# %%
# %matplotlib inline
df_pp.query("年==2015").plot(kind='scatter', x='POP', y='gongshui', 
          title = 'POP与gongshui的关系：分省数据')

# %%
# 解决中文乱码问题
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

df_plot = df_pp.query("年==2015")
df_plot.plot(kind='scatter', x='POP', y='gongshui', 
          title = 'POP与gongshui的关系：分省数据')

# %% [markdown]
# ## (5) 用 numpy.polyfit 做线性回归

# %%
# Regression Using Pandas and Statsmodels
import numpy as np
fit = np.polyfit(x=df_pp.query("年==2015")['POP'], y=df_pp.query("年==2015")['gongshui'], deg=1)

# %%
x=df_plot['POP']
y=df_plot['gongshui']
ax = df_plot.plot(kind='scatter', x='POP', y='gongshui', 
          title = 'POP与gongshui的关系：分省数据')
ax.plot(x, fit[0] * x + fit[1], color='red')
ax.scatter(x, y)

# %% [markdown]
# ## (6) 可视化 使用bokeh 来制图，可交互（HoverTool tooltip）

# %%
df_pp
# Out:
#                  POP  gongshui
# 地区       年
# 北京市      2015   2171     26.80
# 天津市      2015   1547     12.80
# 河北省      2015   7425    135.10
# 山西省      2015   3664     94.00
# 内蒙古自治区   2015   2511    537.00
# 辽宁省      2015   4382    179.00
# 吉林省      2015   2753    331.30
# 黑龙江省     2015   3812    814.10
# 上海市      2015   2415     64.10
# 江苏省      2015   7976    582.10
# 浙江省      2015   5539   1407.10
# 安徽省      2015   6144    914.10
# 福建省      2015   3839   1325.90
# 江西省      2015   4566   2001.20
# 山东省      2015   9847    168.40
# 河南省      2015   9480    287.20
# 湖北省      2015   5852   1015.60
# 湖南省      2015   6783   1919.30
# 广东省      2015  10849   1933.40
# 广西壮族自治区  2015   4796   2433.60
# 海南省      2015    911    198.20
# 重庆市      2015   3017    456.20
# 四川省      2015   8204   2220.50
# 贵州省      2015   3530   1153.70
# 云南省      2015   4742   1871.90
# 西藏自治区    2015    324   3853.00
# 陕西省      2015   3793    333.40
# 甘肃省      2015   2600    164.80
# 青海省      2015    588    589.30
# 宁夏回族自治区  2015    668      9.20
# ...              ...       ...
# 天津市      2006   1075     10.11
# 河北省      2006   6898    107.34
# 山西省      2006   3375     88.52
# 内蒙古自治区   2006   2415    411.29
# 辽宁省      2006   4271    261.36
# 吉林省      2006   2723    353.63
# 黑龙江省     2006   3823    727.93
# 上海市      2006   1964     27.64
# 江苏省      2006   7656    404.40
# 浙江省      2006   5072    903.59
# 安徽省      2006   6110    580.50
# 福建省      2006   3585   1623.48
# 江西省      2006   4339   1629.97
# 山东省      2006   9309    199.32
# 河南省      2006   9392    321.78
# 湖北省      2006   5693    639.69
# 湖南省      2006   6342   1770.29
# 广东省      2006   9442   2216.17
# 广西壮族自治区  2006   4719   1881.08
# 海南省      2006    836    227.59
# 重庆市      2006   2808    380.32
# 四川省      2006   8169   1865.84
# 贵州省      2006   3690    814.63
# 云南省      2006   4483   1711.67
# 西藏自治区    2006    285   4157.14
# 陕西省      2006   3699    275.51
# 甘肃省      2006   2547    184.59
# 青海省      2006    548    569.00
# 宁夏回族自治区  2006    604     10.61
# 新疆维吾尔自治区 2006   2050    953.10
#
# [310 rows x 2 columns]

# %%
# tooltip 工具提示 
df_pp['desc'] = df_pp.index.get_level_values(0)

# %%
# 制图
from bokeh.plotting import figure, output_file, show, output_notebook
from bokeh.models import HoverTool, BoxSelectTool

title = '分省数据' 
xlabel = 'POP：人口' 
ylabel = 'gongshui：供水'

hover = HoverTool(
    tooltips=[
        ( '人口',  '$x{0,F}'), 
        ( '产值',  '$y{0,F}'),
        ( '地区',  '@desc'  ),
    ]
)

TOOLS = [hover, "pan, wheel_zoom, box_zoom, reset, resize"]
fig = figure(plot_width=800, plot_height=600,
           x_axis_label = xlabel, y_axis_label = ylabel, 
           title=title, tools=TOOLS)

df_plot = df_pp.query("年==2015")

fig.circle("POP", "gongshui",
         source = df_plot,
         fill_alpha=0.6, line_color=None, size= 30)

#regression line
xs = [min(df_plot["POP"]), max(df_plot["POP"])]
fig.line(x=xs, y=[ fit[0] * x + fit[1] for x in xs] )

output_notebook() # 输出到IPython/Jupyter Notebook，若要输出到他处需调整
#output_file('by_provinces.htm') # 输出到 htm
show(fig)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d427ee64-89e8-41b1-9471-2b592f35e01a">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7992fd81-edce-439e-8fef-9092b406e6c1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7992fd81-edce-439e-8fef-9092b406e6c1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7992fd81-edce-439e-8fef-9092b406e6c1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7992fd81-edce-439e-8fef-9092b406e6c1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f8552513-b6dc-4c08-9bc6-891cf71010cc":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#1f77b4"},"line_color":{"value":null},"size":{"units":"screen","value":30},"x":{"field":"POP"},"y":{"field":"gongshui"}},"id":"aa92996d-44c5-422d-8eb6-24777e9a9a98","type":"Circle"},{"attributes":{"plot":{"id":"f5199908-0825-46f9-aa64-5e5d8ed2581d","subtype":"Figure","type":"Plot"}},"id":"f4ca040a-8c72-4bdc-b5cb-abffac3d7061","type":"ResizeTool"},{"attributes":{"callback":null},"id":"cc0d554e-02f8-4fed-be57-c5e76a595fab","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":
# %%
## (7) 可视化 使用bokeh 来制图，可交互（slider）

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, push_notebook, show
from bokeh.models import CustomJS, Slider,HoverTool, BoxSelectTool
from bokeh.layouts import column

title = '分省数据' 
xlabel = 'POP：人口大小' 
ylabel = 'gongshui：供水总量'
hover = HoverTool(
    tooltips=[
        ( '人口大小',  '$x{0,F}'), 
        ( '产值大小',  '$y{0,F}'),
        ( '地区',  '@desc'  ),
    ]
)

TOOLS = [hover, "pan, wheel_zoom, box_zoom, reset, resize"]

fig = figure(plot_width=800, plot_height=600,
           x_axis_label = xlabel, y_axis_label = ylabel, 
           title=title, tools=TOOLS)

yr_min = df_pp.index.get_level_values(1).min()
df_plot = df_pp.query("年=={yr}".format(yr=yr_min))
plt = fig.circle("POP", "GDP",
         source = df_plot,
         fill_alpha=0.6, line_color=None, size= 15)


def update_plot(year):
    #plt.data_source.data = df_pp.query("年=={yr}".format(yr=year))
    plt.data_source.data['POP'] = list(df_pp.query("年=={yr}".format(yr=year)).loc[:,['POP']].iloc[:,0].values)
    plt.data_source.data['gongshui'] = list(df_pp.query("年=={yr}".format(yr=year)).loc[:,['gongshui']].iloc[:,0].values)
    plt.data_source.data['地区_年'] = [(x[0],int(year)) for x in plt.data_source.data['地区_年']]

    push_notebook(handle=bokeh_handle)  
    print (year)
    ##### new notebook cell #####

callback = CustomJS(code="""
if (IPython.notebook.kernel !== undefined) {
    var kernel = IPython.notebook.kernel;
    cmd = "update_plot(" + cb_obj.value + ")";
    kernel.execute(cmd, {}, {});
}
""")

slider = Slider(start=df_pp.index.get_level_values(1).min(), 
                end=df_pp.index.get_level_values(1).max(),
                value=1,
                step=1,
                title="年",
                callback=callback)
output_notebook()

bokeh_handle = show(column(slider, fig), notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f859ed8a-0cdc-41ca-9465-2a460a9d82ee">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bc6a8f4a-467a-4797-92e3-4a6e935f57b9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bc6a8f4a-467a-4797-92e3-4a6e935f57b9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("1d51a4b8-deec-46ac-8333-1f0683ec67be", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bc6a8f4a-467a-4797-92e3-4a6e935f57b9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bc6a8f4a-467a-4797-92e3-4a6e935f57b9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8dd505e3-6ace-4452-95af-f47011ba6b64":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"20e3594c-6231-4bd3-9a84-715c07a9086f","type":"HoverTool"},{"id":"a32f0ae6-a8a1-47fa-a22f-2657bde10cdc","type":"PanTool"},{"id":"54fc7f44-b12c-456e-93f1-938d77f6c698","type":"WheelZoomTool"},{"id":"9705f05f-7747-4355-baed-807283a19f41","type":"BoxZoomTool"},{"id":"6ea9fa15-bd02-4d5d-90a2-8f86f3766c4e","type":"ResetTool"},{"id":"68655532-09f4-46f4-abaf-4313dc407276","type":"ResizeTool"}]},"id":"c8de5362-f034-4281-8426-ee3360c7c2f2","type":"Toolbar"},{"attributes":{},"id":"9418a3a7-89c1-4ef3-86a0-a83f945f17ae","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#1f77b4"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"POP"},"y":{"field":"GDP"}},"id":"ebbac33d-ae3b-47e4-ae79-0bbdd3852628","type":"Circle"},{"attributes":{"plot":{"id":"4c0de9e8-a76f-4ec6-9657-a840f274fdf8","subtype":"Figure","type":"Plot"}},"id":"68655532-09f4-46f4-abaf-4313dc407276","type":"ResizeTool"},{"attributes":{"below":[{"id":"974553d2-c268-4543-adca-92689be6fecf","type":"LinearAxis"}],"left":[{"id":"2d5ec733-56f9-41c0-8e80-5eb7c04b13e8","type":"LinearAxis"}],"plot_width":800,"renderers":[{"id":"974553d2-c268-4543-adca-92689be6fecf","type":"LinearAxis"},{"id":"fa8edd8a-667b-49d9-a629-19168cbb1cee","type":"Grid"},{"id":"2d5ec733-56f9-41c0-8e80-5eb7c04b13e8","type":"LinearAxis"},{"id":"8cb58d2e-5742-4afa-b090-8e76084e098d","type":"Grid"},{"id":"922f3b29-7ab0-47e4-9051-3a119314684b","type":"BoxAnnotation"},{"id":"d4b5f625-7ebb-4a03-85a4-8eb7314ff1d4","type":"GlyphRenderer"}],"title":{"id":"13d56509-ead1-4de4-9495-081758ee0cb5","type":"Title"},"tool_events":{"id":"bb38735b-b37d-4f47-aee7-42a7ddfe0e39","type":"ToolEvents"},"toolbar":{"id":"c8de5362-f034-4281-8426-ee3360c7c2f2","type":"Toolbar"},"x_range":{"id":"f6cae276-7763-4209-99c7-03457cbc6ce9","type":"DataRange1d"},"y_range":{"id":"aa6a87d0-5db8-4e1d-811a-5e25e0146f9b","type":"DataRange1d"}},"id":"4c0de9e8-a76f-4ec6-9657-a840f274fdf8","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"f2ed8063-bb54-410a-9acf-0160a2112e7e","type":"BasicTickFormatter"},{"attributes":{},"id":"bb38735b-b37d-4f47-aee7-42a7ddfe0e39","type":"ToolEvents"},{"attributes":{"plot":{"id":"4c0de9e8-a76f-4ec6-9657-a840f274fdf8","subtype":"Figure","type":"Plot"}},"id":"54fc7f44-b12c-456e-93f1-938d77f6c698","type":"WheelZoomTool"},{"attributes":{"code":"\nif (IPython.notebook.kernel !== undefined) {\n    var kernel = IPython.notebook.kernel;\n    cmd = \"update_plot(\" + cb_obj.value + \")\";\n    kernel.execute(cmd, {}, {});\n}\n"},"id":"437eccd4-6e82-4f5d-be05-ba3d270ac7c9","type":"CustomJS"},{"attributes":{"overlay":{"id":"922f3b29-7ab0-47e4-9051-3a119314684b","type":"BoxAnnotation"},"plot":{"id":"4c0de9e8-a76f-4ec6-9657-a840f274fdf8","subtype":"Figure","type":"Plot"}},"id":"9705f05f-7747-4355-baed-807283a19f41","type":"BoxZoomTool"},{"attributes":{"callback":null,"plot":{"id":"4c0de9e8-a76f-4ec6-9657-a840f274fdf8","subtype":"Figure","type":"Plot"},"tooltips":[["\u4eba\u53e3\u5927\u5c0f","$x{0,F}"],["\u4ea7\u503c\u5927\u5c0f","$y{0,F}"],["\u5730\u533a","@desc"]]},"id":"20e3594c-6231-4bd3-9a84-715c07a9086f","type":"HoverTool"},{"attributes":{"plot":null,"text":"\u5206\u7701\u6570\u636e"},"id":"13d56509-ead1-4de4-9495-081758ee0cb5","type":"Title"},{"attributes":{"callback":{"id":"437eccd4-6e82-4f5d-be05-ba3d270ac7c9","type":"CustomJS"},"end":2015,"start":2006,"step":1,"title":"\u5e74","value":1},"id":"e2d6e3ec-aa98-4858-a8af-f357aacd28df","type":"Slider"},{"attributes":{"axis_label":"gongshui\uff1a\u4f9b\u6c34\u603b\u91cf","formatter":{"id":"f2ed8063-bb54-410a-9acf-0160a2112e7e","type":"BasicTickFormatter"},"plot":{"id":"4c0de9e8-a76f-4ec6-9657-a840f274fdf8","subtype":"Figure","type":"Plot"},"ticker":{"id":"813faaa5-c764-4f93-a5b0-869c2fa54b88","type":"BasicTicker"}},"id":"2d5ec7 ...

# %% [markdown]
# ## (8). 算线性期待产值来求哪些省低於期待

# %%
yr = 2015
df_plot = df_pp.query("年=={yr}".format(yr=yr_min))
# Regression Using Pandas and Statsmodels
fit = np.polyfit(x=df_plot['POP'], 
                 y=df_plot['GDP'], deg=1)

# %%
df_plot['expected'] =  [ fit[0] * x + fit[1] for x in df_plot['POP']] 
df_plot['difference'] =  df_plot['GDP'] - df_plot['expected']
df_plot['difference_ratio'] = ( df_plot['GDP'] - df_plot['expected'] ) /df_plot['POP']
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_plot.sort_values(by='difference_ratio')
# Out:
#                 POP       GDP      desc      expected   difference  \
# 地区       年
# 贵州省      2006  3690   2338.98       贵州省   6602.712516 -4263.732516
# 云南省      2006  4483   3988.14       云南省   8077.968779 -4089.828779
# 甘肃省      2006  2547   2277.35       甘肃省   4476.334321 -2198.984321
# 安徽省      2006  6110   6112.50       安徽省  11104.755589 -4992.255589
# 广西壮族自治区  2006  4719   4746.16   广西壮族自治区   8517.010997 -3770.850997
# 四川省      2006  8169   8690.24       四川省  14935.212898 -6244.972898
# 江西省      2006  4339   4820.53       江西省   7810.078613 -2989.548613
# 湖南省      2006  6342   7688.67       湖南省  11536.356413 -3847.686413
# 河南省      2006  9392  12362.79       河南省  17210.418963 -4847.628963
# 陕西省      2006  3699   4743.61       陕西省   6619.455652 -1875.845652
# 湖北省      2006  5693   7617.47       湖北省  10328.990316 -2711.520316
# 重庆市      2006  2808   3907.23       重庆市   4961.885248 -1054.655248
# 山西省      2006  3375   4878.61       山西省   6016.702778 -1138.092778
# 海南省      2006   836   1065.67       海南省   1293.278248  -227.608248
# 新疆维吾尔自治区 2006  2050   3045.26  新疆维吾尔自治区   3551.741178  -506.481178
# 宁夏回族自治区  2006   604    725.90   宁夏回族自治区    861.677424  -135.777424
# 青海省      2006   548    648.50       青海省    757.497915  -108.997915
# 吉林省      2006  2723   4275.12       吉林省   4803.755636  -528.635636
# 黑龙江省     2006  3823   6211.80      黑龙江省   6850.138851  -638.338851
# 河北省      2006  6898  11467.60       河北省  12570.710110 -1103.110110
# 西藏自治区    2006   285    290.76     西藏自治区    268.226292    22.533708
# 内蒙古自治区   2006  2415   4944.25    内蒙古自治区   4230.768336   713.481664
# 福建省      2006  3585   7583.85       福建省   6407.375937  1176.474063
>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>贵州省</th>\n      <th>2006</th>\n      <td>-1.155483</td>\n    </tr>\n    <tr>\n      <th>云南省</th>\n      <th>2006</th>\n      <td>-0.912297</td>\n    </tr>\n    <tr>\n      <th>甘肃省</th>\n      <th>2006</th>\n      <td>-0.863363</td>\n    </tr>\n    <tr>\n      <th>安徽省</th>\n      <th>2006</th>\n      <td>-0.817063</td>\n    </tr>\n    <tr>\n      <th>广西壮族自治区</th>\n      <th>2006</th>\n      <td>-0.799078</td>\n    </tr>\n    <tr>\n      <th>四川省</th>\n      <th>2006</th>\n      <td>-0.764472</td>\n    </tr>\n    <tr>\n      <th>江西省</th>\n      <th>2006</th>\n      <td>-0.688995</td>\n    </tr>\n    <tr>\n      <th>湖南省</th>\n      <th>2006</th>\n      <td>-0.606699</td>\n    </tr>\n    <tr>\n      <th>河南省</th>\n      <th>2006</th>\n      <td>-0.516144</td>\n    </tr>\n    <tr>\n      <th>陕西省</th>\n      <th>2006</th>\n      <td>-0.507122</td>\n    </tr>\n    <tr>\n      <th>湖北省</th>\n      <th>2006</th>\n      <td>-0.476290</td>\n    </tr>\n    <tr>\n      <th>重庆市</th>\n      <th>2006</th>\n      <td>-0.375589</td>\n    </tr>\n    <tr>\n      <th>山西省</th>\n      <th>2006</th>\n      <td>-0.337213</td>\n    </tr>\n    <tr>\n      <th>海南省</th>\n      <th>2006</th>\n      <td>-0.272259</td>\n    </tr>\n    <tr>\n      <th>新疆维吾尔自治区</th>\n      <th>2006</th>\n      <td>-0.247064</td>\n    </tr>\n    <tr>\n      <th>宁夏回族自治区</th>\n      <th>2006</th>\n      <td>-0.224797</td>\n    </tr>\n    <tr>\n      <th>青海省</th>\n      <th>2006</th>\n      <td>-0.198901</td>\n    </tr>\n    <tr>\n      <th>吉林省</th>\n      <th>2006</th>\n      <td>-0.194137</td>\n    </tr>\n    <tr>\n      <th>黑龙江省</th>\n      <th>2006</th>\n      <td>-0.166973</td>\n    </tr>\n    <tr>\n      <th>河北省</th>\n      <th>2006</th>\n      <td>-0.159917</td>\n    </tr>\n    <tr>\n      <th>西藏自治区</th>\n      <th>2006</th>\n      <td>0.079066</td>\n    </tr>\n    <tr>\n      <th>内蒙古自治区</th>\n      <th>2006</th>\n      <td>0.295438</td>\n    </tr>\n    <tr>\n      <th>福建省</th>\n      <th>2006</th>\n      <td>0.328166</td>\n    </tr>\n    <tr>\n      <th>辽宁省</th>\n      <th>2006</th>\n      <td>0.379524</td>\n    </tr>\n    <tr>\n      <th>山东省</th>\n      <th>2006</th>\n      <td>0.520376</td>\n    </tr>\n    <tr>\n      <th>广东省</th>\n      <th>2006</th>\n      <td>0.983301</td>\n    </tr>\n    <tr>\n      <th>江苏省</th>\n      <th>2006</th>\n      <td>1.013740</td>\n    </tr>\n    <tr>\n      <th>浙江省</th>\n      <th>2006</th>\n      <td>1.290370</td>\n    </tr>\n    <tr>\n      <th>天津市</th>\n      <th>2006</th>\n      <td>2.534733</td>\n    </tr>\n    <tr>\n      <th>北京市</th>\n      <th>2006</th>\n      <td>3.373726</td>\n    </tr>\n    <tr>\n      <th>上海市</th>\n      <th>2006</th>\n      <td>3.656053</td>\n    </tr>\n  </tbody>\n</table>'

# %%
with open("table.htm", "w", encoding="utf8") as fp:
    fp.write
