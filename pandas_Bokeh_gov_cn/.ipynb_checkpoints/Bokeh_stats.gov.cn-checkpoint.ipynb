# %% [markdown]
# # 分省指标数据之使用与制图
# * 数据处理+制图 使用[pandas](http://pandas.pydata.org/pandas-docs/stable/install.html)
# * 制图 使用 [bokeh](http://bokeh.pydata.org/en/latest/docs/installation.html)

# %% [markdown]
# ## (1) 取/连结 数据

# %%
import pandas as pd   # 数据分析模块 （Python Data Analysis Library Python）

# %%
# 列出同目录之.csv档以检查
import glob
print(glob.glob("*.csv"))
# Out:
# ['fsnd_GDP_A020101.csv', 'fsnd_POP_A030101.csv']

# %%
# 第1次尝试 
# 读GDP数据，赋与df   (df指 dataframe)   pd.DataFrame 是前面最早调用的 pandas
df_try = pd.read_table("fsnd_GDP_A020101.csv",   # 档名
                       encoding = 'utf8',        # 编码
                      )
# 出错的话，是国家数据网下载的数据并没有用 UTF-8 (档首无BOM)编码
# 使用Notepad++按编码-->  转换至  UTF-8 (档首无BOM)编码

# %%
# 看看有什麽？
df_try
# Out:
#                                            数据库：分省年度数据
# 0                                       指标：地区生产总值(亿元)
# 1                                            时间：最近10年
# 2   地区,2015年,2014年,2013年,2012年,2011年,2010年,2009年,2...
# 3   北京市,23014.59,21330.83,19800.81,17879.40,16251....
# 4   天津市,16538.19,15726.93,14442.01,12893.88,11307....
# 5   河北省,29806.11,29421.15,28442.95,26575.01,24515....
# 6   山西省,12766.49,12761.49,12665.25,12112.83,11237....
# 7   内蒙古自治区,17831.51,17770.19,16916.50,15880.58,143...
# 8   辽宁省,28669.02,28626.58,27213.22,24846.43,22226....
# 9   吉林省,14063.13,13803.14,13046.40,11939.24,10568....
# 10  黑龙江省,15083.67,15039.38,14454.91,13691.58,12582...
# 11  上海市,25123.45,23567.70,21818.15,20181.72,19195....
# 12  江苏省,70116.38,65088.32,59753.37,54058.22,49110....
# 13  浙江省,42886.49,40173.03,37756.59,34665.33,32318....
# 14  安徽省,22005.63,20848.75,19229.34,17212.05,15300....
# 15  福建省,25979.82,24055.76,21868.49,19701.78,17560....
# 16  江西省,16723.78,15714.63,14410.19,12948.88,11702....
# 17  山东省,63002.33,59426.59,55230.32,50013.24,45361....
# 18  河南省,37002.16,34938.24,32191.30,29599.31,26931....
# 19  湖北省,29550.19,27379.22,24791.83,22250.45,19632....
# 20  湖南省,28902.21,27037.32,24621.67,22154.23,19669....
# 21  广东省,72812.55,67809.85,62474.79,57067.92,53210....
# 22  广西壮族自治区,16803.12,15672.89,14449.90,13035.10,11...
# 23  海南省,3702.76,3500.72,3177.56,2855.54,2522.66,20...
# 24  重庆市,15717.27,14262.60,12783.26,11409.60,10011....
# 25  四川省,30053.10,28536.66,26392.07,23872.80,21026....
# 26  贵州省,10502.56,9266.39,8086.86,6852.20,5701.84,4...
# 27  云南省,13619.17,12814.59,11832.31,10309.47,8893.1...
# 28  西藏自治区,1026.39,920.83,815.67,701.03,605.83,507....
# 29  陕西省,18021.86,17689.94,16205.45,14453.68,12512....
# 30  甘肃省,6790.32,6836.82,6330.69,5650.20,5020.37,41...
# 31  青海省,2417.05,2303.32,2122.06,1893.54,1670.44,13...
# 32  宁夏回族自治区,2911.77,2752.10,2577.57,2341.29,2102.2...
# 33  新疆维吾尔自治区,9324.80,9273.46,8443.84,7505.31,6610....
# 34  注：本表按当年价格计算。2004年以前地区生产总值数据执行《国民经济行业分类》（GB/T47...
# 35                                         数据来源：国家统计局

# %%
# 第2次尝试 
# 指定数据标题为原始数据之第几行
df    = pd.read_table("fsnd_GDP_A020101.csv",   # 档名
                       encoding = 'utf8',       # 编码
                       header = 
# 29   1353.31   1203.92    919.11    725.90
# 30   4277.05   4183.21   3523.16   3045.26

# %%
# .head()只看前面5笔
df.head()
# Out:
#        地区     2015年     2014年     2013年     2012年     2011年     2010年  \
# 0     北京市  23014.59  21330.83  19800.81  17879.40  16251.93  14113.58
# 1     天津市  16538.19  15726.93  14442.01  12893.88  11307.28   9224.46
# 2     河北省  29806.11  29421.15  28442.95  26575.01  24515.76  20394.26
# 3     山西省  12766.49  12761.49  12665.25  12112.83  11237.55   9200.86
# 4  内蒙古自治区  17831.51  17770.19  16916.50  15880.58  14359.88  11672.00
#
#       2009年     2008年     2007年     2006年
# 0  12153.03  11115.00   9846.81   8117.78
# 1   7521.85   6719.01   5252.76   4462.74
# 2  17235.48  16011.97  13607.32  11467.60
# 3   7358.31   7315.40   6024.45   4878.61
# 4   9740.25   8496.20   6423.18   4944.25

# %%
# 小结：要处理数据得看原始数据的格式好不好处理
# 现在读2个数据，分别放在df_GDP及df_POP
df_GDP= pd.read_table("fsnd_GDP_A020101.csv",   # 档名
                       encoding = 'utf8',       # 编码
                       header = 3,              # 指定数据的标题为原始数据之第3行
                       skiprows = [35,36],      # 原始数据之第35, 36行跳过不计
                       sep =','                 # 分隔符设为',' read_table内置分隔符为\t
                      )
df_POP= pd.read_table("fsnd_POP_A030101.csv",   # 档名
                       encoding = 'utf8',       # 编码
                       header = 3,              # 指定数据的标题为原始数据之第3行
                       skiprows = [35,36],      # 原始数据之第35, 36行跳过不计
                       sep =','                 # 分隔符设为',' read_table内置分隔符为\t
                      )

# %% [markdown]
# ## (2) 准备 数据  （型态）
# * 此练习目标在於取最新一年的数据
# * 比较这两指标数据是否有关连性
# * i.e. 人口较多是否和产值较多相关连

# %%
# 先处理 df_GDP
df = df_GDP

# %%
# 目前之columns列
df.columns
# Out:
# Index(['地区', '2015年', '2014年', '2013年', '2012年', '2011年', '2010年', '2009年',
#        '2008年', '2007年', '2006年'],
#       dtype='object')

# %%
# 目前之index 索引(栏)
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df['地区'].head()
# Out:
# 0       北京市
# 1       天津市
# 2       河北省
# 3       山西省
# 4    内蒙古自治区
# Name: 地区, dtype: object

# %%
# 此写法不行，不能以数字开头 
df.2007年
# Out:
#   File "<ipython-input-14-636ec1e109bc>", line 2
#     df.2007年
#           ^
# SyntaxError: invalid syntax

# %%
# 此写法可以
df['2007年'].head()

# %%
# 数据型态dtypes 
df.dtypes
# Out:
# 地区        object
# 2015年    float64
# 2014年    float64
# 2013年    float64
# 2012年    float64
# 2011年    float64
# 2010年    float64
# 2009年    float64
# 2008年    float64
# 2007年    float64
# 2006年    float64
# dtype: object

# %%
# 把df 的栏位用列表推导的方式清理掉'年'这个字符後转换成整数
df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns]
df.columns
# Out:
# Index(['地区', 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006], dtype='object')

# %%
# 求最新的一年
years = [ x for x in df.columns if x!='地区'] 
max(years)
# Out:
# 2015

# %%
# pd.melt() 相当於Tableau 的数据透视
df_melted = pd.melt(df, id_vars=['地区'], value_vars=years)

# %%
df_melted.columns
# Out:
# Index(['地区', 'variable', 'value'], dtype='object')

# %%
df_melted.columns = ['地区', '年', 'GDP']
df_melted
# Out:
#            地区     年       GDP
# 0         北京市  2015  23014.59
# 1         天津市  2015  16538.19
# 2         河北省  2015  29806.11
# 3         山西省  2015  12766.49
# 4      内蒙古自治区  2015  17831.51
# 5         辽宁省  2015  28669.02
# 6         吉林省  2015  14063.13
# 7        黑龙江省  2015  15083.67
# 8         上海市  2015  25123.45
# 9         江苏省  2015  70116.38
# 10        浙江省  2015  42886.49
# 11        安徽省  2015  22005.63
# 12        福建省  2015  25979.82
# 13        江西省  2015  16723.78
# 14        山东省  2015  63002.33
# 15        河南省  2015  37002.16
# 16        湖北省  2015  29550.19
# 17        湖南省  2015  28902.21
# 18        广东省  2015  72812.55
# 19    广西壮族自治区  2015  16803.12
# 20        海南省  2015   3702.76
# 21        重庆市  2015  15717.27
# 22        四川省  2015  30053.10
# 23        贵州省  2015  10502.56
# 24        云南省  2015  13619.17
# 25      西藏自治区  2015   1026.39
# 26        陕西省  2015  18021.86
# 27        甘肃省  2015   6790.32
# 28        青海省  2015   2417.05
# 29    宁夏回族自治区  2015   2911.77
# ..        ...   ...       ...
# 280       天津市  2006   4462.74
# 281       河北省  2006  11467.60
# 282       山西省  2006   4878.61
# 283    内蒙古自治区  2006   4944.25
# 284       辽宁省  2006   9304.52
# 285       吉林省  2006   4275.12
# 286      黑龙江省  2006   6211.80
# 287       上海市  2006  10572.24
# 288       江苏省  2006  21742.05
# 289       浙江省  2006  15718.47
# 290       安徽省  2006   6112.50
# 291       福建省  2006   7583.85
# 292       江西省  2006   4820.53
# 293       山东省  2006  21900.19
# 294       河南省  2006  12362.79
# 295       湖北省  2006   7617.47
# 296       湖南省  2006   7688.67
# 297       广东省  2006  26587.76
# 298   广西壮族自治区  2006   4746.16
# 299       海南省  2006   1065.67
# 300       重庆市  2006   3907.23
# 301       四川省  2006   8690.24
# 302       贵州省  2006   2338.98
# 303       云南省  2006   3988.14
# 304     西藏自治区  2006    290.76
# 305       陕西省  2006   4743.61
# 306       甘肃省  2006   2277.35
# 307       青海省  2006    648.50
# 308   宁夏回族自治区  2006    725.90
# 309  新疆维吾尔自治区  2006   3045.26
#
# [310 rows x 3 columns]

# %%
df_GDP_done = df_melted

# %%
# 再处理 df_POP
df = df_POP
df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns]
years = [ x for x in df.columns if x!='地区'] 
df_melted = pd.melt(df, id_vars=['地区'], value_vars=years)
df_melted.columns = ['地区', '年', 'POP']
df_POP_done = df_melted
df_POP_done
# Out:
#            地区     年    POP
# 0         北京市  2015   2171
# 1         天津市  2015   1547
# 2         河北省  2015   7425
# 3         山西省  2015   3664
# 4      内蒙古自治区  2015   2511
# 5         辽宁省  2015   4382
# 6         吉林省  2015   2753
# 7        黑龙江省  2015   3812
# 8         上海市  2015   2415
# 9         江苏省  2015   7976
# 10        浙江省  2015   5539
# 11        安徽省  2015   6144
# 12        福建省  2015   3839
# 13        江西省  2015   4566
# 14        山东省  2015   9847
# 15        河南省  2015   9480
# 16        湖北省  2015   5852
# 17        湖南省  2015   6783
# 18        广东省  2015  10849
# 19    广西壮族自治区  2015   4796
# 20        海南省  2015    911
# 河南省      2006   9392  12362.79
# 湖北省      2006   5693   7617.47
# 湖南省      2006   6342   7688.67
# 广东省      2006   9442  26587.76
# 广西壮族自治区  2006   4719   4746.16
# 海南省      2006    836   1065.67
# 重庆市      2006   2808   3907.23
# 四川省      2006   8169   8690.24
# 贵州省      2006   3690   2338.98
# 云南省      2006   4483   3988.14
# 西藏自治区    2006    285    290.76
# 陕西省      2006   3699   4743.61
# 甘肃省      2006   2547   2277.35
# 青海省      2006    548    648.50
# 宁夏回族自治区  2006    604    725.90
# 新疆维吾尔自治区 2006   2050   3045.26
#
# [310 rows x 2 columns]

# %%
df_pp = df_p.drop(["地区_GDP","年_GDP"], axis=1).set_index(["地区","年"])

# %%
df_pp.query("年==2015")
# Out:
#                  POP       GDP
# 地区       年
# 北京市      2015   2171  23014.59
# 天津市      2015   1547  16538.19
# 河北省      2015   7425  29806.11
# 山西省      2015   3664  12766.49
# 内蒙古自治区   2015   2511  17831.51
# 辽宁省      2015   4382  28669.02
# 吉林省      2015   2753  14063.13
# 黑龙江省     2015   3812  15083.67
# 上海市      2015   2415  25123.45
# 江苏省      2015   7976  70116.38
# 浙江省      2015   5539  42886.49
# 安徽省      2015   6144  22005.63
# 福建省      2015   3839  25979.82
# 江西省      2015   4566  16723.78
# 山东省      2015   9847  63002.33
# 河南省      2015   9480  37002.16
# 湖北省      2015   5852  29550.19
# 湖南省      2015   6783  28902.21
# 广东省      2015  10849  72812.55
# 广西壮族自治区  2015   4796  16803.12
# 海南省      2015    911   3702.76
# 重庆市      2015   3017  15717.27
# 四川省      2015   8204  30053.10
# 贵州省      2015   3530  10502.56
# 云南省      2015   4742  13619.17
# 西藏自治区    2015    324   1026.39
# 陕西省      2015   3793  18021.86
# 甘肃省      2015   2600   6790.32
# 青海省      2015    588   2417.05
# 宁夏回族自治区  2015    668   2911.77
# 新疆维吾尔自治区 2015   2360   9324.80

# %% [markdown]
# ## (4) 可视化 使用pands 自带的plot来制图

# %%
# %matplotlib inline
df_pp.query("年==2015").plot(kind='scatter', x='POP', y='GDP', 
          title = 'POP与GDP的关系：分省数据')

# %%
# 解决中文乱码问题
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

df_plot = df_pp.query("年==2015")
df_plot.plot(kind='scatter', x='POP', y='GDP', 
          title = 'POP与GDP的关系：分省数据')

# %% [markdown]
# ## (5) 用 numpy.polyfit 做线性回归

# %%
# Regression Using Pandas and Statsmodels
import numpy as np
fit = np.polyfit(x=df_pp.query("年==2015")['POP'], y=df_pp.query("年==2015")['GDP'], deg=1)

# %%
x=df_plot['POP']
y=df_plot['GDP']
ax = df_plot.plot(kind='scatter', x='POP', y='GDP', 
          title = 'POP与GDP的关系：分省数据')
ax.plot(x, fit[0] * x + fit[1], color='red')
ax.scatter(x, y)

# %% [markdown]
# ## (6) 可视化 使用bokeh 来制图，可交互（HoverTool tooltip）

# %%
df_pp
# Out:
#                  POP       GDP
# 地区       年
# 北京市      2015   2171  23014.59
# 天津市      2015   1547  16538.19
# 河北省      2015   7425  29806.11
# 山西省      2015   3664  12766.49
# 内蒙古自治区   2015   2511  17831.51
# 辽宁省      2015   4382  28669.02
# 吉林省      2015   2753  14063.13
# 黑龙江省     2015   3812  15083.67
# 上海市      2015   2415  25123.45
# 江苏省      2015   7976  70116.38
# 浙江省      2015   5539  42886.49
# 安徽省      2015   6144  22005.63
# 福建省      2015   3839  25979.82
# 江西省      2015   4566  16723.78
# 山东省      2015   9847  63002.33
# 河南省      2015   9480  37002.16
# 湖北省      2015   5852  29550.19
# 湖南省      2015   6783  28902.21
# 广东省      2015  10849  72812.55
# 广西壮族自治区  2015   4796  16803.12
# 海南省      2015    911   3702.76
# 重庆市      2015   3017  15717.27
# 四川省      2015   8204  30053.10
# 贵州省      2015   3530  10502.56
# 云南省      2015   4742  13619.17
# 西藏自治区    2015    324   1026.39
# 陕西省      2015   3793  18021.86
# 甘肃省      2015   2600   6790.32
# 青海省      2015    588   2417.05
# 宁夏回族自治区  2015    668   2911.77
# ...              ...       ...
# 天津市      2006   1075   4462.74
# 河北省      2006   6898  11467.60
# 山西省      2006   3375   4878.61
# 内蒙古自治区   2006   2415   4944.25
# 辽宁省      2006   4271   9304.52
# 吉林省      2006   2723   4275.12
# 黑龙江省     2006   3823   6211.80
# 上海市      2006   1964  10572.24
# 江苏省      2006   7656  21742.05
# 浙江省      2006   5072  15718.47
# 安徽省      2006   6110   6112.50
# 福建省      2006   3585   7583.85
# 江西省      2006   4339   4820.53
# 山东省      2006   9309  21900.19
# 河南省      2006   9392  12362.79
# 湖北省      2006   5693   7617.47
# 湖南省      2006   6342   7688.67
# 广东省      2006   9442  26587.76
# 广西壮族自治区  2006   4719   4746.16
# 海南省      2006    836   1065.67
# 重庆市      2006   2808   3907.23
# 四川省      2006   8169   8690.24
# 贵州省      2006   3690   2338.98
# 云南省      2006   4483   3988.14
# 西藏自治区    2006    285    290.76
# 陕西省      2006   3699   4743.61
# 甘肃省      2006   2547   2277.35
# 青海省      2006    548    648.50
# 宁夏回族自治区  2006    604    725.90
# 新疆维吾尔自治区 2006   2050   3045.26
#
# [310 rows x 2 columns]

# %%
# tooltip 工具提示 
df_pp['desc'] = df_pp.index.get_level_values(0)

# %%
# 制图
from bokeh.plotting import figure, output_file, show, output_notebook
from bokeh.models import HoverTool, BoxSelectTool

title = '分省数据' 
xlabel = 'POP：人口' 
ylabel = 'GDP：产值'

hover = HoverTool(
    tooltips=[
        ( '人口',  '$x{0,F}'), 
        ( '产值',  '$y{0,F}'),
        ( '地区',  '@desc'  ),
    ]
)

TOOLS = [hover, "pan, wheel_zoom, box_zoom, reset, resize"]
fig = figure(plot_width=800, plot_height=600,
           x_axis_label = xlabel, y_axis_label = ylabel, 
           title=title, tools=TOOLS)

df_plot = df_pp.query("年==2015")

fig.circle("POP", "GDP",
         source = df_plot,
         fill_alpha=0.6, line_color=None, size= 30)

#regression line
xs = [min(df_plot["POP"]), max(df_plot["POP"])]
fig.line(x=xs, y=[ fit[0] * x + fit[1] for x in xs] )

output_notebook() # 输出到IPython/Jupyter Notebook，若要输出到他处需调整
#output_file('by_provinces.htm') # 输出到 htm
show(fig)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id
},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[324,10849],"y":[867.6294903625551,58517.310071751344]}},"id":"2dba1b5d-c058-4ea0-927c-2e8ca626a6f4","type":"ColumnDataSource"},{"attributes":{},"id":"1933f2c0-fdb3-4a3b-9b87-f8b88a7f4280","type":"BasicTicker"},{"attributes":{"data_source":{"id":"2dba1b5d-c058-4ea0-927c-2e8ca626a6f4","type":"ColumnDataSource"},"glyph":{"id":"a05573c8-06e9-45c1-a95e-f6e214481fd4","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"9ae6978e-c78e-4712-8ffe-ef7deeaffd87","type":"Line"},"selection_glyph":null},"id":"11fccaa6-7e66-48c9-a3f9-d351eb1a08ab","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a05573c8-06e9-45c1-a95e-f6e214481fd4","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9ae6978e-c78e-4712-8ffe-ef7deeaffd87","type":"Line"},{"attributes":{"plot":{"id":"4fbbb92f-bf3e-4abc-a591-1a2539b5c6f9","subtype":"Figure","type":"Plot"}},"id":"1888ad2d-3ab4-4c33-82c7-12d13c6a841b","type":"ResetTool"},{"attributes":{"plot":{"id":"4fbbb92f-bf3e-4abc-a591-1a2539b5c6f9","subtype":"Figure","type":"Plot"}},"id":"38ffabec-5bc9-4 ...

# %%
## (7) 可视化 使用bokeh 来制图，可交互（slider）

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, push_notebook, show
from bokeh.models import CustomJS, Slider,HoverTool, BoxSelectTool
from bokeh.layouts import column

title = '分省数据' 
xlabel = 'POP：人口大小' 
ylabel = 'GDP：产值大小'
hover = HoverTool(
    tooltips=[
        ( '人口大小',  '$x{0,F}'), 
        ( '产值大小',  '$y{0,F}'),
        ( '地区',  '@desc'  ),
    ]
)

TOOLS = [hover, "pan, wheel_zoom, box_zoom, reset, resize"]

fig = figure(plot_width=800, plot_height=600,
           x_axis_label = xlabel, y_axis_label = ylabel, 
           title=title, tools=TOOLS)

yr_min = df_pp.index.get_level_values(1).min()
df_plot = df_pp.query("年=={yr}".format(yr=yr_min))
plt = fig.circle("POP", "GDP",
         source = df_plot,
         fill_alpha=0.6, line_color=None, size= 15)


def update_plot(year):
    #plt.data_source.data = df_pp.query("年=={yr}".format(yr=year))
    plt.data_source.data['POP'] = list(df_pp.query("年=={yr}".format(yr=year)).loc[:,['POP']].iloc[:,0].values)
    plt.data_source.data['GDP'] = list(df_pp.query("年=={yr}".format(yr=year)).loc[:,['GDP']].iloc[:,0].values)
    plt.data_source.data['地区_年'] = [(x[0],int(year)) for x in plt.data_source.data['地区_年']]

    push_notebook(handle=bokeh_handle)  
    print (year)
    ##### new notebook cell #####

callback = CustomJS(code="""
if (IPython.notebook.kernel !== undefined) {
    var kernel = IPython.notebook.kernel;
    cmd = "update_plot(" + cb_obj.value + ")";
    kernel.execute(cmd, {}, {});
}
""")

slider = Slider(start=df_pp.index.get_level_values(1).min(), 
                end=df_pp.index.get_level_values(1).max(),
                value=1,
                step=1,
                title="年",
                callback=callback)
output_notebook()

bokeh_handle = show(column(slider, fig), notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0292e3d3-9784-4fc8-b63c-38ef957526c9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7d9d30e5-37ef-4aac-b61c-adf287293b18"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7d9d30e5-37ef-4aac-b61c-adf287293b18").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("a40b496f-773b-471c-98e0-0895a9d744b4", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7d9d30e5-37ef-4aac-b61c-adf287293b18");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7d9d30e5-37ef-4aac-b61c-adf287293b18' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a720aee9-c29f-47a3-88ce-de413fc9599f":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0473d545-54ce-424d-88c9-ac5b6d4dea88","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ffca7c80-5535-48e7-8d45-5e82b9558f4c","subtype":"Figure","type":"Plot"}},"id":"f87c299c-ee8b-4a6a-a4ee-49e9087c02c9","type":"PanTool"},{"attributes":{},"id":"86e663d7-32fe-4258-9cad-1f4a468d33c4","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"ffca7c80-5535-48e7-8d45-5e82b9558f4c","subtype":"Figure","type":"Plot"}},"id":"db1a981e-3ccd-4715-9b89-b7dcca8ed8ec","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"0473d545-54ce-424d-88c9-ac5b6d4dea88","type":"BoxAnnotation"},"plot":{"id":"ffca7c80-5535-48e7-8d45-5e82b9558f4c","subtype":"Figure","type":"Plot"}},"id":"be67bcdb-7553-4a39-a934-37ad3ce193a4","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"ffca7c80-5535-48e7-8d45-5e82b9558f4c","subtype":"Figure","type":"Plot"}},"id":"dd886617-e026-4b31-9965-8e4ac81b7669","type":"ResetTool"},{"attributes":{"plot":{"id":"ffca7c80-5535-48e7-8d45-5e82b9558f4c","subtype":"Figure","type":"Plot"}},"id":"6824dff4-53df-4f92-8a60-f3ccd0109c67","type":"ResizeTool"},{"attributes":{"data_source":{"id":"4dfbbce1-3b8b-438d-a2fe-852cda9b4742","type":"ColumnDataSource"},"glyph":{"id":"f60fd47f-f345-4da2-890f-ab51e756647b","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"0e0dd0cb-e7dd-4bbe-86e3-500292ba6585","type":"Circle"},"selection_glyph":null},"id":"d7fe0ef6-4a7e-4ee6-ab22-11887caae122","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"POP"},"y":{"field":"GDP"}},"id":"0e0dd0cb-e7dd-4bbe-86e3-500292ba6585","type":"Circle"},{"attributes":{"children":[{"id":"860c56c8-d79a-46fc-82d2-12f56e2305bd","type":"Slider"}]},"id":"c4b13e55-dcbe-40d5-a74e-e7281108bf74","type":"WidgetBox"},{"attributes":{},"id":"3816138f-aa90-42c7-ae25-5e5851a87abf","type":"BasicTickFormatter"},{"attributes":{"callback":{"id":"02ae4370-1b42-4c12-9a44-221e809f499b","type":"CustomJS"},"end":2015,"start":2006,"step":1,"title":"\u5e74","value":1},"id":"860c56c8-d79a-46fc-82d2-12f56e2305bd","type":"Slider"},{"attributes":{"code":"\nif (IPython.notebook.kernel !== undefined) {\n    var kernel = IPython.notebook.kernel;\n    cmd = \"update_plot(\" + cb_obj.value + \")\";\n    kernel.execute(cmd, {}, {});\n}\n"},"id":"02ae4370-1b42-4c12-9a44-221e809f499b","type":"CustomJS"},{"attributes":{"plot":null,"text":"\u5206\u7701\u6570\u636e"},"id":"54ee5f8d-b00f-4270-b5c8-3414d0194d69","type":"Title"},{"attributes":{"callback":null,"plot":{"id":"ffca7c80-5535-48e7-8d45-5e82b9558f4c","subtype":"Figure","type":"Plot"},"tooltips":[["\u4eba\u53e3\u5927\u5c0f","$x{0,F}"],["\u4ea7\u503c\u5927\u5c0f","$y{0,F}"],["\u5730\u533a","@desc"]]},"id":"efb838f8-a29a-499a-ab83-5c9e54e414e6","type":"HoverTool"},{"attributes":{"children":[{"id":"c4b13e55-dcbe-40d5-a74e-e7281108bf74","type":"WidgetBox"},{"id":"ffca7c80-5535-48e7-8d45-5e82b9558f4c","subtype":"Figure","type":"Plot"}]},"id":"fb9e61bc-1b3a-46cc-938a-83a25eaa3611","type":"Column"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"efb838f8-a29a-499a-ab83-5c9e54e414e6","type":"HoverTool"},{"id":"f87c299c-ee8b-4a6a-a4ee-49e9087c02c9","type":"PanTool"},{"id":"db1a981e-3ccd-4715-9b89-b7dcca8ed8ec","type":"WheelZoomTool"},{"id":"be67bcdb-7553-4a39-a934-37ad3ce193a4","type":"BoxZoomTool"},{"id":"dd886617-e026-4b31-9965-8e4ac81b7669","type":"ResetTool"},{"id":"6824dff4-53df-4f92-8a60-f3ccd0109c67","type":"ResizeTool"}]},"id":"344500e ...

# %% [markdown]
# ## (8). 算线性期待产值来求哪些省低於期待

# %%
yr = 2015
df_plot = df_pp.query("年=={yr}".format(yr=yr_min))
# Regression Using Pandas and Statsmodels
fit = np.polyfit(x=df_plot['POP'], 
                 y=df_plot['GDP'], deg=1)

# %%
df_plot['expected'] =  [ fit[0] * x + fit[1] for x in df_plot['POP']] 
df_plot['difference'] =  df_plot['GDP'] - df_plot['expected']
df_plot['difference_ratio'] = ( df_plot['GDP'] - df_plot['expected'] ) /df_plot['POP']
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# c:\python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# c:\python36\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_plot.sort_values(by='difference_ratio')
# Out:
#                 POP       GDP      desc      expected   difference  \
# 地区       年
# 贵州省      2006  3690   2338.98       贵州省   6602.712516 -4263.732516
# 云南省      2006  4483   3988.14       云南省   8077.968779 -4089.828779
# 甘肃省      2006  2547   2277.35       甘肃省   4476.334321 -2198.984321
# 安徽省      2006  6110   6112.50       安徽省  11104.755589 -4992.255589
# 广西壮族自治区  2006  4719   4746.16   广西壮族自治区   8517.010997 -3770.850997
# 四川省      2006  8169   8690.24       四川省  14935.212898 -6244.972898
# 江西省      2006  4339   4820.53       江西省   7810.078613 -2989.548613
# 湖南省      2006  6342   7688.67       湖南省  11536.356413 -3847.686413
# 河南省      2006  9392  12362.79       河南省  17210.418963 -4847.628963
# 陕西省      2006  3699   4743.61       陕西省   6619.455652 -1875.845652
# 湖北省      2006  5693   7617.47       湖北省  10328.990316 -2711.520316
# 重庆市      2006  2808   3907.23       重庆市   4961.885248 -1054.655248
# 山西省      2006  3375   4878.61       山西省   6016.702778 -1138.092778
# 海南省      2006   836   1065.67       海南省   1293.278248  -227.608248
# 新疆维吾尔自治区 2006  2050   3045.26  新疆维吾尔自治区   3551.741178  -506.481178
# 宁夏回族自治区  2006   604    725.90   宁夏回族自治区    861.677424  -135.777424
# 青海省      2006   548    648.50       青海省    757.497915  -108.997915
# 吉林省      2006  2723   4275.12       吉林省   4803.755636  -528.635636
# 黑龙江省     2006  3823   6211.80      黑龙江省   6850.138851  -638.338851
# 河北省      2006  6898  11467.60       河北省  12570.710110 -1103.110110
# 西藏自治区    2006   285    290.76     西藏自治区    268.226292    22.533708
# 内蒙古自治区   2006  2415   4944.25    内蒙古自治区   4230.768336   713.481664
# 福建省      2006  3585   7583.85       福建省   6407.375937  1176.474063
>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>贵州省</th>\n      <th>2006</th>\n      <td>-1.155483</td>\n    </tr>\n    <tr>\n      <th>云南省</th>\n      <th>2006</th>\n      <td>-0.912297</td>\n    </tr>\n    <tr>\n      <th>甘肃省</th>\n      <th>2006</th>\n      <td>-0.863363</td>\n    </tr>\n    <tr>\n      <th>安徽省</th>\n      <th>2006</th>\n      <td>-0.817063</td>\n    </tr>\n    <tr>\n      <th>广西壮族自治区</th>\n      <th>2006</th>\n      <td>-0.799078</td>\n    </tr>\n    <tr>\n      <th>四川省</th>\n      <th>2006</th>\n      <td>-0.764472</td>\n    </tr>\n    <tr>\n      <th>江西省</th>\n      <th>2006</th>\n      <td>-0.688995</td>\n    </tr>\n    <tr>\n      <th>湖南省</th>\n      <th>2006</th>\n      <td>-0.606699</td>\n    </tr>\n    <tr>\n      <th>河南省</th>\n      <th>2006</th>\n      <td>-0.516144</td>\n    </tr>\n    <tr>\n      <th>陕西省</th>\n      <th>2006</th>\n      <td>-0.507122</td>\n    </tr>\n    <tr>\n      <th>湖北省</th>\n      <th>2006</th>\n      <td>-0.476290</td>\n    </tr>\n    <tr>\n      <th>重庆市</th>\n      <th>2006</th>\n      <td>-0.375589</td>\n    </tr>\n    <tr>\n      <th>山西省</th>\n      <th>2006</th>\n      <td>-0.337213</td>\n    </tr>\n    <tr>\n      <th>海南省</th>\n      <th>2006</th>\n      <td>-0.272259</td>\n    </tr>\n    <tr>\n      <th>新疆维吾尔自治区</th>\n      <th>2006</th>\n      <td>-0.247064</td>\n    </tr>\n    <tr>\n      <th>宁夏回族自治区</th>\n      <th>2006</th>\n      <td>-0.224797</td>\n    </tr>\n    <tr>\n      <th>青海省</th>\n      <th>2006</th>\n      <td>-0.198901</td>\n    </tr>\n    <tr>\n      <th>吉林省</th>\n      <th>2006</th>\n      <td>-0.194137</td>\n    </tr>\n    <tr>\n      <th>黑龙江省</th>\n      <th>2006</th>\n      <td>-0.166973</td>\n    </tr>\n    <tr>\n      <th>河北省</th>\n      <th>2006</th>\n      <td>-0.159917</td>\n    </tr>\n    <tr>\n      <th>西藏自治区</th>\n      <th>2006</th>\n      <td>0.079066</td>\n    </tr>\n    <tr>\n      <th>内蒙古自治区</th>\n      <th>2006</th>\n      <td>0.295438</td>\n    </tr>\n    <tr>\n      <th>福建省</th>\n      <th>2006</th>\n      <td>0.328166</td>\n    </tr>\n    <tr>\n      <th>辽宁省</th>\n      <th>2006</th>\n      <td>0.379524</td>\n    </tr>\n    <tr>\n      <th>山东省</th>\n      <th>2006</th>\n      <td>0.520376</td>\n    </tr>\n    <tr>\n      <th>广东省</th>\n      <th>2006</th>\n      <td>0.983301</td>\n    </tr>\n    <tr>\n      <th>江苏省</th>\n      <th>2006</th>\n      <td>1.013740</td>\n    </tr>\n    <tr>\n      <th>浙江省</th>\n      <th>2006</th>\n      <td>1.290370</td>\n    </tr>\n    <tr>\n      <th>天津市</th>\n      <th>2006</th>\n      <td>2.534733</td>\n    </tr>\n    <tr>\n      <th>北京市</th>\n      <th>2006</th>\n      <td>3.373726</td>\n    </tr>\n    <tr>\n      <th>上海市</th>\n      <th>2006</th>\n      <td>3.656053</td>\n    </tr>\n  </tbody>\n</table>'

# %%
with open("table.htm", "w", encoding="utf8") as fp:
    fp.write
